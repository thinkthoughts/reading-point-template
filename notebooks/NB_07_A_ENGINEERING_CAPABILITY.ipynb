# %% [markdown]
# # NB_07_B_LEADING_SPECIFICATION
#
# Candidate notebook continuing RP_07 from Candidate A.

# %% [markdown]
# ## Reading Point RP_07
#
# **Inherited Engineering Dialogue**
#
# - Engineering Reliability
#
# **Engineering Objective**
#
# > Expand Engineering Capability.

# %% [markdown]
# ## Admitted Engineering Dialogue
#
# **Engineering Reliability stabilizes Engineering Capability.**

# %% [markdown]
# ## Specification Search
#
# Primary Dialogue
#
# ```text
# Engineering Capability
#         ↓
# Leading Specification
# ```
#
# Supporting Context
#
# ```text
# Engineering Reliability
#
# Trailing Generalization
# ```

# %% [markdown]
# ## Candidate Engineering Statements
#
# - Engineering Capability stabilizes Leading Specification.
# - Engineering Capability supports Leading Specification.
# - Engineering Capability develops Leading Specification.
# - Engineering Capability specifies Leading Specification.
#
# **Status:** Specification Search (no admission yet).

# %%
READING_POINT = {
    "id": "RP_07",
    "candidate": "07_B",
    "objective": "Expand Engineering Capability.",
    "admitted_statement":
        "Engineering Reliability stabilizes Engineering Capability.",
    "primary_dialogue": (
        "Engineering Capability",
        "Leading Specification",
    ),
    "supporting_context": (
        "Engineering Reliability",
        "Trailing Generalization",
    ),
    "status": "specification-search",
}
READING_POINT

# %% [markdown]
# *Admissible generalizations trail leading specifications.*
