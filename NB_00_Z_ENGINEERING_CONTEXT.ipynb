# %% [markdown]
# # NB_00_Z_ENGINEERING_CONTEXT
#
# ## Engineering Context
#
# This notebook initializes, validates, exports, and visualizes the engineering context for the `sensors-becker` repository.
#
# **Notebook stage:** Z — Engineering Context
# **Repository:** `sensors-becker`
# **Status:** Developing
#
# ---
#
# *Admissible generalizations trail leading specifications.*

# %%
from __future__ import annotations

import sys
from pathlib import Path


def find_repository_root(start: Path) -> Path:
    """Find the repository root containing pyproject.toml."""

    current = start.resolve()

    for candidate in (current, *current.parents):
        if (candidate / "pyproject.toml").exists():
            return candidate

    raise FileNotFoundError(
        "Could not locate repository root containing pyproject.toml"
    )


REPOSITORY_ROOT = find_repository_root(Path.cwd())
SRC_DIR = REPOSITORY_ROOT / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

REPOSITORY_ROOT

# %%
from sensors_becker.context import RepositoryContext, default_context
from sensors_becker.export import export_context_bundle
from sensors_becker.figures import (
    create_engineering_cycle_figure,
    create_engineering_object_figure,
    export_default_figures,
)
from sensors_becker.paths import ensure_runtime_directories
from sensors_becker.validation import validate_context

# %% [markdown]
# ## Runtime Directories
#
# The notebook initializes the standard repository runtime directories before creating outputs.

# %%
runtime_directories = ensure_runtime_directories()

for directory in runtime_directories:
    print(directory.relative_to(REPOSITORY_ROOT))

# %% [markdown]
# ## Initialize Engineering Context
#
# The default context provides the repository identity, engineering object sequence, engineering paths, measured engineering states, and current specification boundary.

# %%
context: RepositoryContext = default_context()
context

# %%
validate_context(context)

print("Engineering context validation: PASSED")

# %% [markdown]
# ## Repository Identity

# %%
repository_identity = {
    "repository": context.repository,
    "initiated": context.initiated,
    "status": context.status,
    "engineering_object": context.engineering_object,
    "current_specification": context.current_specification,
}

repository_identity

# %% [markdown]
# ## Engineering Object Sequence

# %%
for index, item in enumerate(context.object_sequence):
    marker = "└──" if index == len(context.object_sequence) - 1 else "├──"
    print(f"{marker} {item}")

# %% [markdown]
# ## Engineering Paths

# %%
for path in context.engineering_paths:
    print(f"• {path}")

# %% [markdown]
# ## Measured Engineering States

# %%
for state in context.measured_engineering_states:
    print(f"• {state}")

# %% [markdown]
# ## Current Specification Boundary
#
# The repository currently specifies the engineering object, engineering paths, and initial measured engineering states.
#
# Becker-specific engineering constraints and refinements remain open for continued engineering sessions.

# %%
development_state = {
    "engineering_constraints": list(context.engineering_constraints),
    "engineering_refinements": list(context.engineering_refinements),
}

development_state

# %% [markdown]
# ## Export Engineering Context

# %%
json_path, yaml_path = export_context_bundle(context)

print(json_path.relative_to(REPOSITORY_ROOT))
print(yaml_path.relative_to(REPOSITORY_ROOT))

# %% [markdown]
# ## Engineering Object Figure

# %%
object_figure = create_engineering_object_figure(context)
object_figure

# %% [markdown]
# ## Engineering Development Cycle

# %%
cycle_figure = create_engineering_cycle_figure(context)
cycle_figure

# %% [markdown]
# ## Export Figures

# %%
object_figure_path, cycle_figure_path = export_default_figures(context)

print(object_figure_path.relative_to(REPOSITORY_ROOT))
print(cycle_figure_path.relative_to(REPOSITORY_ROOT))

# %% [markdown]
# ## Verify Outputs

# %%
generated_outputs = (
    json_path,
    yaml_path,
    object_figure_path,
    cycle_figure_path,
)

for path in generated_outputs:
    assert path.exists()
    assert path.stat().st_size > 0
    print(f"✓ {path.relative_to(REPOSITORY_ROOT)}")

# %% [markdown]
# ## Notebook Outputs
#
# This notebook generates:
#
# ```text
# outputs/exports/engineering_context.json
# outputs/exports/engineering_context.yaml
# outputs/figures/engineering_object_sequence.png
# outputs/figures/engineering_development_cycle.png
# ```
#
# These outputs establish the executable engineering context inherited by subsequent notebooks.

# %% [markdown]
# ## Leading Specification

# %%
print(context.leading_specification)

# %% [markdown]
# ## Specified Next Notebook
#
# ```text
# NB_01_A_ENGINEERING_OBJECT.ipynb
# ```
#
# The next notebook develops the engineering object as an executable and validated object sequence.
#
# ---
#
# *Engineering context supports continued engineering development.*
#
# *Admissible generalizations trail leading specifications.*
